// %%
public class MaximoComunDivisor {
    
    public int mcdEuclides(int m, int n)
    {
        System.out.println(" **** INICIO EUCLIDES *****");
        int tmp;
        while(m > 0)
        {
            System.out.println("m=" + m + "; n=" + n);
            tmp = m;
            m = n % m;
            n = tmp;
        }
        System.out.println("m=" + m + "; n=" + n + " --> mcd = n = " + n);
        System.out.println(" **** FIN EUCLIDES ***** \n");        
        return n;
        
    }

    public int mcd(int m, int n)
    {
        System.out.println(" **** INICIO ALGORITMO CLÁSICO *****");
        int i = Math.min(n, m);
        while(!(m % i == 0 && n % i == 0)){            
            System.out.println("i = : " + i);
            i = i -1;
        }
        System.out.println("i = : " + i + " --> mcd");
        System.out.println(" **** FIN ALGORITMO CLÁSICO ***** \n");
        return i;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr509fe3c2.MaximoComunDivisor

// %%
    MaximoComunDivisor calculadorMcd = new MaximoComunDivisor();
    int m = 280, n = 160;
    System.out.println("Cálculo del MCD entre: " + m + " y " + n + "\n");
    calculadorMcd.mcd(m, n);
    calculadorMcd.mcdEuclides(m, n);
// Out:
// Cálculo del MCD entre: 280 y 160
//
//  **** INICIO ALGORITMO CLÁSICO *****
// i = : 160
// i = : 159
// i = : 158
// i = : 157
// i = : 156
// i = : 155
// i = : 154
// i = : 153
// i = : 152
// i = : 151
// i = : 150
// i = : 149
// i = : 148
// i = : 147
// i = : 146
// i = : 145
// i = : 144
// i = : 143
// i = : 142
// i = : 141
// i = : 140
// i = : 139
// i = : 138
// i = : 137
// i = : 136
// i = : 135
// i = : 134
// i = : 133
// i = : 132
// i = : 131
// i = : 130
// i = : 129
// i = : 128
// i = : 127
// i = : 126
// i = : 125
// i = : 124
// i = : 123
// i = : 122
// i = : 121
// i = : 120
// i = : 119
// i = : 118
// i = : 117
// i = : 116
// i = : 115
// i = : 114
// i = : 113
// i = : 112
// i = : 111
// i = : 110
// i = : 109
// i = : 108
// i = : 107
// i = : 106
// i = : 105
// i = : 104
// i = : 103
// i = : 102
// i = : 101
// i = : 100
// i = : 99
// i = : 98
// i = : 97
// i = : 96
// i = : 95
// i = : 94
// i = : 93
// i = : 92
// i = : 91
// i = : 90
// i = : 89
// i = : 88
// i = : 87
// i = : 86
// i = : 85
// i = : 84
// i = : 83
// i = : 82
// i = : 81
// i = : 80
// i = : 79
// i = : 78
// i = : 77
// i = : 76
// i = : 75
// i = : 74
// i = : 73
// i = : 72
// i = : 71
// i = : 70
// i = : 69
// i = : 68
// i = : 67
// i = : 66
// i = : 65
// i = : 64
// i = : 63
// i = : 62
// i = : 61
// i = : 60
// i = : 59
// i = : 58
// i = : 57
// i = : 56
// i = : 55
// i = : 54
// i = : 53
// i = : 52
// i = : 51
// i = : 50
// i = : 49
// i = : 48
// i = : 47
// i = : 46
// i = : 45
// i = : 44
// i = : 43
// i = : 42
// i = : 41
// i = : 40 --> mcd
//  **** FIN ALGORITMO CLÁSICO *****
//
//  **** INICIO EUCLIDES *****
// m=280; n=160
// m=160; n=280
// m=120; n=160
// m=40; n=120
// m=0; n=40 --> mcd = n = 40
//  **** FIN EUCLIDES *****
// null
